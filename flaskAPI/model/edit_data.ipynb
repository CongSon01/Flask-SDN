# %%
import pandas as pd 
import json
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf 
import random
ip = str(json.load(open('/home/onos/Downloads/flask_SDN/config.json'))['ip_local'])
file_name = str(ip).split('.')[-1] + '_lstm'

dataframe = pd.read_csv('/home/onos/Downloads/' + file_name + '.csv')
dataframe
# Out:
# 2022-08-08 18:32:38.959992: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-08 18:32:38.960018: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#         Unnamed: 0        IpSDN                  src                  dst  \
# 0                0  10.20.0.200  of:0000000000000006  of:0000000000000007
# 1                1  10.20.0.200  of:000000000000002c  of:000000000000002d
# 2                2  10.20.0.200  of:000000000000002c  of:000000000000002d
# 3                3  10.20.0.200  of:000000000000003d  of:000000000000003f
# 4                4  10.20.0.200  of:0000000000000005  of:0000000000000004
# ...            ...          ...                  ...                  ...
# 144162      144162  10.20.0.200  of:0000000000000001  of:0000000000000002
# 144163      144163  10.20.0.200  of:0000000000000004  of:000000000000003c
# 144164      144164  10.20.0.200  of:0000000000000002  of:0000000000000001
# 144165      144165  10.20.0.200  of:0000000000000005  of:0000000000000004
# 144166      144166  10.20.0.200  of:0000000000000004  of:0000000000000005
#
#         byteReceived   byteSent  delay  linkUtilization   overhead  \
# 0           4.274906  10.506868    332         0.000000   7.390887
# 1           8.412595   0.000280    856         0.336515   4.206437
# 2           8.412595   0.000280    856         0.336515   4.206437
# 3          18.924586  18.923776    484         1.000000  18.924181
# 4           8.413157   0.000278     27         0.000000   4.206717
# ...              ...        ...    ...              ...        ...
# 144162      0.090584  31.445310     83         1.000000  15.767947
# 144163      4.365061   4.363172     82         0.562064   4.364116
# 144164    120.217520   2.000688     76         0.951297  61.109104
# 144165      2.361479   2.360848     65         0.014010   2.361163
# 144166    100.870192  12.417447    160         1.000000  56.643819
#
#         packetLoss  ratio_overhead  label
# 0         0.000000        0.000000      0
# 1         0.000000        0.000000      0
# 2         0.000000        0.000000      0
# 3         0.000000        0.000000      0
# 4         0.000000        0.000000      0
# ...            ...             ...    ...
# 144162    0.999988       89.102556      0
# 144163    0.000000       23.937809      1
# 144164    0.000000      348.194880      0
# 144165    0.000000       12.492363      0
# 144166    0.041711      322.678969      0
#
# [144167 rows x 12 columns]

# %%
dataframe.drop(['Unnamed: 0', 'label'] , axis=1, inplace=True)

# %%
dataframe
# Out:
#               IpSDN                  src                  dst  byteReceived  \
# 0       10.20.0.200  of:0000000000000006  of:0000000000000007      4.274906
# 1       10.20.0.200  of:000000000000002c  of:000000000000002d      8.412595
# 2       10.20.0.200  of:000000000000002c  of:000000000000002d      8.412595
# 3       10.20.0.200  of:000000000000003d  of:000000000000003f     18.924586
# 4       10.20.0.200  of:0000000000000005  of:0000000000000004      8.413157
# ...             ...                  ...                  ...           ...
# 144162  10.20.0.200  of:0000000000000001  of:0000000000000002      0.090584
# 144163  10.20.0.200  of:0000000000000004  of:000000000000003c      4.365061
# 144164  10.20.0.200  of:0000000000000002  of:0000000000000001    120.217520
# 144165  10.20.0.200  of:0000000000000005  of:0000000000000004      2.361479
# 144166  10.20.0.200  of:0000000000000004  of:0000000000000005    100.870192
#
#          byteSent  delay  linkUtilization   overhead  packetLoss  \
# 0       10.506868    332         0.000000   7.390887    0.000000
# 1        0.000280    856         0.336515   4.206437    0.000000
# 2        0.000280    856         0.336515   4.206437    0.000000
# 3       18.923776    484         1.000000  18.924181    0.000000
# 4        0.000278     27         0.000000   4.206717    0.000000
# ...           ...    ...              ...        ...         ...
# 144162  31.445310     83         1.000000  15.767947    0.999988
# 144163   4.363172     82         0.562064   4.364116    0.000000
# 144164   2.000688     76         0.951297  61.109104    0.000000
# 144165   2.360848     65         0.014010   2.361163    0.000000
# 144166  12.417447    160         1.000000  56.643819    0.041711
#
#         ratio_overhead
# 0             0.000000
# 1             0.000000
# 2             0.000000
# 3             0.000000
# 4             0.000000
# ...                ...
# 144162       89.102556
# 144163       23.937809
# 144164      348.194880
# 144165       12.492363
# 144166      322.678969
#
# [144167 rows x 10 columns]

# %%
def _nor_with_min(x, min, max):
    return (max - x) / (max - min)
def _nor_with_max(x, min, max):
    return (x - min) / (max - min)
def get_label(_d, _l, _p, _o, _a1, _a2, _a3, _a4):
    return _d*_a1 + _l*_a2 + _p*_a3 + _o*_a4

# %%
link_costs = get_label(_nor_with_max(dataframe['delay'].values, min(dataframe['delay'].values), max(dataframe['delay'].values)), 
                        _nor_with_min(dataframe['linkUtilization'].values, min(dataframe['linkUtilization'].values), max(dataframe['linkUtilization'].values)),
                        _nor_with_max(dataframe['packetLoss'], min(dataframe['packetLoss'].values), max(dataframe['packetLoss'].values)), 
                        _nor_with_max(dataframe['overhead'], min(dataframe['overhead'].values), max(dataframe['overhead'].values)),
0.25, 0.25, 0.25, 0.25)

# %%
dataframe['link_costs'] = link_costs

# %%
dataframe
# Out:
#               IpSDN                  src                  dst  byteReceived  \
# 0       10.20.0.200  of:0000000000000006  of:0000000000000007      4.274906
# 1       10.20.0.200  of:000000000000002c  of:000000000000002d      8.412595
# 2       10.20.0.200  of:000000000000002c  of:000000000000002d      8.412595
# 3       10.20.0.200  of:000000000000003d  of:000000000000003f     18.924586
# 4       10.20.0.200  of:0000000000000005  of:0000000000000004      8.413157
# ...             ...                  ...                  ...           ...
# 144162  10.20.0.200  of:0000000000000001  of:0000000000000002      0.090584
# 144163  10.20.0.200  of:0000000000000004  of:000000000000003c      4.365061
# 144164  10.20.0.200  of:0000000000000002  of:0000000000000001    120.217520
# 144165  10.20.0.200  of:0000000000000005  of:0000000000000004      2.361479
# 144166  10.20.0.200  of:0000000000000004  of:0000000000000005    100.870192
#
#          byteSent  delay  linkUtilization   overhead  packetLoss  \
# 0       10.506868    332         0.000000   7.390887    0.000000
# 1        0.000280    856         0.336515   4.206437    0.000000
# 2        0.000280    856         0.336515   4.206437    0.000000
# 3       18.923776    484         1.000000  18.924181    0.000000
# 4        0.000278     27         0.000000   4.206717    0.000000
# ...           ...    ...              ...        ...         ...
# 144162  31.445310     83         1.000000  15.767947    0.999988
# 144163   4.363172     82         0.562064   4.364116    0.000000
# 144164   2.000688     76         0.951297  61.109104    0.000000
# 144165   2.360848     65         0.014010   2.361163    0.000000
# 144166  12.417447    160         1.000000  56.643819    0.041711
#
#         ratio_overhead  link_costs
# 0             0.000000    0.353671
# 1             0.000000    0.384037
# 2             0.000000    0.384037
# 3             0.000000    0.178443
# 4             0.000000    0.270220
# ...                ...         ...
# 144162       89.102556    0.322160
# 144163       23.937809    0.143362
# 144164      348.194880    0.233936
# 144165       12.492363    0.269634
# 144166      322.678969    0.237349
#
# [144167 rows x 11 columns]

# %% [markdown]
# # Tiền Xử Lý

# %%
dataframe.drop(['IpSDN', 'src', 'dst', 'byteReceived', 'byteSent'], axis=1, inplace=True)

# %%
y = dataframe['link_costs']
X = dataframe.drop(columns='link_costs')
y_set = y.values
X_set = X.values.astype('float32')

# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
X_set = scaler.fit_transform(X_set)

# %%
# import sklearn.external.joblib as extjoblib
import joblib
scaler_filename = "/home/onos/Downloads/flask_SDN/scaler.save"
joblib.dump(scaler, scaler_filename)
# Out:
# ['/home/onos/Downloads/flask_SDN/scaler.save']

# %%
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint, EarlyStopping
train_X, test_X, train_y, test_y = train_test_split(X_set, y_set, test_size = 0.3)
val_X,test_X, val_y,test_y = train_test_split(test_X, test_y, test_size=0.3)

# %%
# Thay đổi shape của tập X
time_steps = 1
input_train_lstm = train_X.reshape( train_X.shape[0], time_steps, train_X.shape[1] )
input_val_lstm = val_X.reshape( val_X.shape[0], time_steps, val_X.shape[1])
input_test_lstm = test_X.reshape( test_X.shape[0], time_steps, test_X.shape[1])

# %%
# #Building the LSTM Model
lstm = Sequential()
# unit = hidden state
lstm.add(LSTM(units=64, input_shape=(time_steps, input_train_lstm.shape[2]), activation='relu', return_sequences=True))

lstm.add(LSTM(units=128, activation='relu', return_sequences=True))

lstm.add(LSTM(units=64, activation='relu', return_sequences=False))


# lop dau vao hinh tron
lstm.add(Dense(1)) 

opt = tf.keras.optimizers.Adam(learning_rate=0.001)
mape = tf.keras.losses.MeanAbsolutePercentageError()
lstm.compile(loss='mean_squared_error', optimizer=opt)
lstm.summary()
file_name = "/home/onos/Downloads/flask_SDN/lstmlocal.hdf5"
checkpoint = ModelCheckpoint(file_name, monitor='mean_squared_error', save_best_only=True, mode='auto', period=1, verbose=1)
# early = EarlyStopping(monitor='accuracy')
epoch=100

from time import time
start = time()

history = lstm.fit(input_train_lstm,
                   train_y,
                   epochs=epoch,
                   verbose=1,
                   callbacks=[checkpoint])
                   
print('Total training time: ', time()-start)
# Out:
# 2022-08-08 18:32:41.508639: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-08-08 18:32:41.508670: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-08-08 18:32:41.508684: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (onos-virtual-machine): /proc/driver/nvidia/version does not exist
# 2022-08-08 18:32:41.508900: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 64)             17920
#
#  lstm_1 (LSTM)               (None, 1, 128)            98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 166,209
# Trainable params: 166,209
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/100
# 3147/3154 [============================>.] - ETA: 0s - loss: 7.2219e-04WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 15s 4ms/step - loss: 7.2067e-04
# Epoch 2/100
# 3148/3154 [============================>.] - ETA: 0s - loss: 5.8415e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 13s 4ms/step - loss: 5.8348e-07
# Epoch 3/100
# 3145/3154 [============================>.] - ETA: 0s - loss: 6.3074e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 6.3066e-07
# Epoch 4/100
# 3144/3154 [============================>.] - ETA: 0s - loss: 5.9580e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 5.9443e-07
# Epoch 5/100
# 3143/3154 [============================>.] - ETA: 0s - loss: 5.5656e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 5.5622e-07
# Epoch 6/100
# 3148/3154 [============================>.] - ETA: 0s - loss: 5.6530e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 5.6444e-07
# Epoch 7/100
# 3150/3154 [============================>.] - ETA: 0s - loss: 5.5192e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 5.5142e-07
# Epoch 8/100
# 3150/3154 [============================>.] - ETA: 0s - loss: 5.0558e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 5.0519e-07
# Epoch 9/100
# 3149/3154 [============================>.] - ETA: 0s - loss: 4.0155e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 4.0102e-07
# Epoch 10/100
# 3149/3154 [============================>.] - ETA: 0s - loss: 4.6044e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 4.5991e-07
# Epoch 11/100
# 3148/3154 [============================>.] - ETA: 0s - loss: 4.3824e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 4.3917e-07
# Epoch 12/100
# 3142/3154 [============================>.] - ETA: 0s - loss: 3.9306e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.9275e-07
# Epoch 13/100
# 3149/3154 [============================>.] - ETA: 0s - loss: 4.2485e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 4.2461e-07
# Epoch 14/100
# 3151/3154 [============================>.] - ETA: 0s - loss: 3.5842e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.5814e-07
# Epoch 15/100
# 3142/3154 [============================>.] - ETA: 0s - loss: 3.5290e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.5261e-07
# Epoch 16/100
# 3144/3154 [============================>.] - ETA: 0s - loss: 3.7574e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.7484e-07
# Epoch 17/100
# 3144/3154 [============================>.] - ETA: 0s - loss: 3.8638e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.8537e-07
# Epoch 18/100
# 3147/3154 [============================>.] - ETA: 0s - loss: 4.2479e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 4.2570e-07
# Epoch 19/100
# 3145/3154 [============================>.] - ETA: 0s - loss: 3.2022e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.1984e-07
# Epoch 20/100
# 3142/3154 [============================>.] - ETA: 0s - loss: 3.4048e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.3971e-07
# Epoch 21/100
# 3151/3154 [============================>.] - ETA: 0s - loss: 3.1292e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.1291e-07
# Epoch 22/100
# 3150/3154 [============================>.] - ETA: 0s - loss: 3.2442e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.2406e-07
# Epoch 23/100
# 3151/3154 [============================>.] - ETA: 0s - loss: 2.9732e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 13s 4ms/step - loss: 2.9709e-07
# Epoch 24/100
# 3147/3154 [============================>.] - ETA: 0s - loss: 2.6754e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 2.6709e-07
# Epoch 25/100
# 3150/3154 [============================>.] - ETA: 0s - loss: 3.1255e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 10s 3ms/step - loss: 3.1221e-07
# Epoch 26/100
# 3143/3154 [============================>.] - ETA: 0s - loss: 2.8806e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 2.8717e-07
# Epoch 27/100
# 3145/3154 [============================>.] - ETA: 0s - loss: 3.0367e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.0307e-07
# Epoch 28/100
# 3147/3154 [============================>.] - ETA: 0s - loss: 3.4999e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.4962e-07
# Epoch 29/100
# 3147/3154 [============================>.] - ETA: 0s - loss: 3.2862e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.2804e-07
# Epoch 30/100
# 3148/3154 [============================>.] - ETA: 0s - loss: 2.6951e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 2.7050e-07
# Epoch 31/100
# 3150/3154 [============================>.] - ETA: 0s - loss: 2.7024e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 2.7032e-07
# Epoch 32/100
# 3153/3154 [============================>.] - ETA: 0s - loss: 3.0587e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 13s 4ms/step - loss: 3.0581e-07
# Epoch 33/100
# 3148/3154 [============================>.] - ETA: 0s - loss: 3.1404e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.1352e-07
# Epoch 34/100
# 3147/3154 [============================>.] - ETA: 0s - loss: 2.4288e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 13s 4ms/step - loss: 2.4250e-07
# Epoch 35/100
# 3153/3154 [============================>.] - ETA: 0s - loss: 1.9732e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 14s 4ms/step - loss: 1.9728e-07
# Epoch 36/100
# 3143/3154 [============================>.] - ETA: 0s - loss: 2.7959e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 2.8597e-07
# Epoch 37/100
# 3142/3154 [============================>.] - ETA: 0s - loss: 2.2597e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 2.2520e-07
# Epoch 38/100
# 3151/3154 [============================>.] - ETA: 0s - loss: 3.0057e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.0033e-07
# Epoch 39/100
# 3146/3154 [============================>.] - ETA: 0s - loss: 2.7236e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 2.7173e-07
# Epoch 40/100
# 3142/3154 [============================>.] - ETA: 0s - loss: 2.3800e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 2.3716e-07
# Epoch 41/100
# 3143/3154 [============================>.] - ETA: 0s - loss: 3.1869e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 3.1890e-07
# Epoch 42/100
# 3153/3154 [============================>.] - ETA: 0s - loss: 1.9649e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 1.9645e-07
# Epoch 43/100
# 3149/3154 [============================>.] - ETA: 0s - loss: 1.8960e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 1.8936e-07
# Epoch 44/100
# 3145/3154 [============================>.] - ETA: 0s - loss: 2.8931e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 2.8945e-07
# Epoch 45/100
# 3143/3154 [============================>.] - ETA: 0s - loss: 2.4034e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 2.3955e-07
# Epoch 46/100
# 3147/3154 [============================>.] - ETA: 0s - loss: 2.5687e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 2.5635e-07
# Epoch 47/100
# 3142/3154 [============================>.] - ETA: 0s - loss: 2.1318e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 2.1275e-07
# Epoch 48/100
# 3151/3154 [============================>.] - ETA: 0s - loss: 1.9500e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 1.9486e-07
# Epoch 49/100
# 3151/3154 [============================>.] - ETA: 0s - loss: 2.4425e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 2.4405e-07
# Epoch 50/100
# 3144/3154 [============================>.] - ETA: 0s - loss: 2.0001e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 13s 4ms/step - loss: 1.9952e-07
# Epoch 51/100
# 3152/3154 [============================>.] - ETA: 0s - loss: 2.3626e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 13s 4ms/step - loss: 2.3614e-07
# Epoch 52/100
# 3153/3154 [============================>.] - ETA: 0s - loss: 2.3503e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 13s 4ms/step - loss: 2.3498e-07
# Epoch 53/100
# 3144/3154 [============================>.] - ETA: 0s - loss: 2.2220e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 2.2155e-07
# Epoch 54/100
# 3147/3154 [============================>.] - ETA: 0s - loss: 2.6775e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 13s 4ms/step - loss: 2.6720e-07
# Epoch 55/100
# 3148/3154 [============================>.] - ETA: 0s - loss: 2.1965e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 13s 4ms/step - loss: 2.1933e-07
# Epoch 56/100
# 3153/3154 [============================>.] - ETA: 0s - loss: 1.9962e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 13s 4ms/step - loss: 1.9959e-07
# Epoch 57/100
# 3148/3154 [============================>.] - ETA: 0s - loss: 2.4245e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 13s 4ms/step - loss: 2.4202e-07
# Epoch 58/100
# 3142/3154 [============================>.] - ETA: 0s - loss: 1.7339e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.7277e-07
# Epoch 59/100
# 3145/3154 [============================>.] - ETA: 0s - loss: 2.4100e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 2.4072e-07
# Epoch 60/100
# 3147/3154 [============================>.] - ETA: 0s - loss: 1.6859e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 1.7082e-07
# Epoch 61/100
# 3154/3154 [==============================] - ETA: 0s - loss: 1.9190e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.9190e-07
# Epoch 62/100
# 3141/3154 [============================>.] - ETA: 0s - loss: 2.7224e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 2.7118e-07
# Epoch 63/100
# 3150/3154 [============================>.] - ETA: 0s - loss: 1.5860e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 1.5846e-07
# Epoch 64/100
# 3147/3154 [============================>.] - ETA: 0s - loss: 2.2711e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 2.2665e-07
# Epoch 65/100
# 3143/3154 [============================>.] - ETA: 0s - loss: 1.8125e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 1.8085e-07
# Epoch 66/100
# 3154/3154 [==============================] - ETA: 0s - loss: 1.9115e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.9115e-07
# Epoch 67/100
# 3147/3154 [============================>.] - ETA: 0s - loss: 2.0122e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 2.0085e-07
# Epoch 68/100
# 3149/3154 [============================>.] - ETA: 0s - loss: 1.5764e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.5742e-07
# Epoch 69/100
# 3151/3154 [============================>.] - ETA: 0s - loss: 1.7247e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 1.7235e-07
# Epoch 70/100
# 3146/3154 [============================>.] - ETA: 0s - loss: 2.5672e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 2.5612e-07
# Epoch 71/100
# 3144/3154 [============================>.] - ETA: 0s - loss: 2.1513e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 2.1448e-07
# Epoch 72/100
# 3141/3154 [============================>.] - ETA: 0s - loss: 1.7469e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.7425e-07
# Epoch 73/100
# 3143/3154 [============================>.] - ETA: 0s - loss: 1.8824e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 1.8826e-07
# Epoch 74/100
# 3150/3154 [============================>.] - ETA: 0s - loss: 1.8494e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 1.8475e-07
# Epoch 75/100
# 3150/3154 [============================>.] - ETA: 0s - loss: 1.8520e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.8501e-07
# Epoch 76/100
# 3145/3154 [============================>.] - ETA: 0s - loss: 1.7256e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.7260e-07
# Epoch 77/100
# 3142/3154 [============================>.] - ETA: 0s - loss: 1.6664e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 1.6680e-07
# Epoch 78/100
# 3151/3154 [============================>.] - ETA: 0s - loss: 1.8353e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 1.8381e-07
# Epoch 79/100
# 3145/3154 [============================>.] - ETA: 0s - loss: 2.2727e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 2.2666e-07
# Epoch 80/100
# 3154/3154 [==============================] - ETA: 0s - loss: 2.0759e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 2.0759e-07
# Epoch 81/100
# 3149/3154 [============================>.] - ETA: 0s - loss: 1.4230e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.4211e-07
# Epoch 82/100
# 3141/3154 [============================>.] - ETA: 0s - loss: 2.1964e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 2.2076e-07
# Epoch 83/100
# 3146/3154 [============================>.] - ETA: 0s - loss: 1.2839e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 12s 4ms/step - loss: 1.2810e-07
# Epoch 84/100
# 3143/3154 [============================>.] - ETA: 0s - loss: 1.6337e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.6362e-07
# Epoch 85/100
# 3146/3154 [============================>.] - ETA: 0s - loss: 1.8459e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.8415e-07
# Epoch 86/100
# 3141/3154 [============================>.] - ETA: 0s - loss: 1.4293e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.4243e-07
# Epoch 87/100
# 3153/3154 [============================>.] - ETA: 0s - loss: 1.7677e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.7677e-07
# Epoch 88/100
# 3151/3154 [============================>.] - ETA: 0s - loss: 2.0121e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 2.0105e-07
# Epoch 89/100
# 3150/3154 [============================>.] - ETA: 0s - loss: 1.1518e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.1506e-07
# Epoch 90/100
# 3143/3154 [============================>.] - ETA: 0s - loss: 2.1087e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 2.1523e-07
# Epoch 91/100
# 3154/3154 [==============================] - ETA: 0s - loss: 1.4884e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.4884e-07
# Epoch 92/100
# 3145/3154 [============================>.] - ETA: 0s - loss: 1.6539e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 3ms/step - loss: 1.6497e-07
# Epoch 93/100
# 3151/3154 [============================>.] - ETA: 0s - loss: 1.7498e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.7487e-07
# Epoch 94/100
# 3154/3154 [==============================] - ETA: 0s - loss: 1.5215e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.5215e-07
# Epoch 95/100
# 3142/3154 [============================>.] - ETA: 0s - loss: 1.8024e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.7959e-07
# Epoch 96/100
# 3143/3154 [============================>.] - ETA: 0s - loss: 2.0767e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 3ms/step - loss: 2.0876e-07
# Epoch 97/100
# 3147/3154 [============================>.] - ETA: 0s - loss: 1.5781e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 3ms/step - loss: 1.5762e-07
# Epoch 98/100
# 3147/3154 [============================>.] - ETA: 0s - loss: 1.4536e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 4ms/step - loss: 1.4508e-07
# Epoch 99/100
# 3144/3154 [============================>.] - ETA: 0s - loss: 1.5619e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 3ms/step - loss: 1.5586e-07
# Epoch 100/100
# 3144/3154 [============================>.] - ETA: 0s - loss: 1.8331e-07WARNING:tensorflow:Can save best model only with mean_squared_error available, skipping.
# 3154/3154 [==============================] - 11s 3ms/step - loss: 1.8275e-07
# Total training time:  1185.2576808929443
